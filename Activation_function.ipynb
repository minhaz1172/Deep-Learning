# %% [markdown]
# Relu fUNCTION

# %%
import numpy as np
import matplotlib.pyplot as plt
def relu(x):
    return max(0, x)

# %%
relu(10)  # Expected output: 10
# Out:
# 10

# %%
relu(-5)  # Expected output: 0
# Out:
# 0

# %%
import numpy as np

def relu(x):
    return np.maximum(0, x)

x = np.array([-1, 0, 1, 2, 3])
output = relu(x)
print("ReLU Output:", output)
# Expected output: [0 0 1 2 3]
# Out:
# ReLU Output: [0 0 1 2 3]

# %% [markdown]
# # Plot Relu Function

# %%
plt.plot(x, output, label='ReLU', color='blue')
plt.title('ReLU Activation Function')
plt.xlabel('Input')
plt.ylabel('ReLU Output')
plt.grid(True)
plt.show()
# Expected output: A plot showing the ReLU function, which is 0 for negative inputs and linear for positive inputs.

# %% [markdown]
# # Leaky Relu Function

# %%
def leaky_relu(x,alpha=0.01):
    return np.where(x>0,x,alpha*x)
# Expected output: 0.01 * x for negative x, and x for positive x

# %%
x=np.array([-1,0,1,2,3])
output=leaky_relu(x)
print("Leaky ReLU Output:", output)
# Expected output: [-0.01  0.    1.    2.    3.  ]
# Out:
# Leaky ReLU Output: [-0.01  0.    1.    2.    3.  ]

# %%
#plot the leaky relu function
plt.plot(x, output, label='Leaky ReLU', color='red')
plt.title('Leaky ReLU Activation Function')
plt.xlabel('Input')
plt.ylabel('Leaky ReLU Output')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Exponenetial Linear unit (ELU)

# %%
#FORMULA
# y = alpha * x for x < 0, and y = x for x >= 0

def elu(x,alpha=1.0):
    return np.where(x>0,x,alpha*(np.exp(x)-1))
# Expected output: alpha * (exp(x) - 1) for negative x, and x for positive x

# %%
x=np.array([-1,0,1,2,3])
output=elu(x)
print("Elu Output:", output)
# Expected output: [-0.01  0.    1.    2.    3.  ]
# Out:
# Elu Output: [-0.63212056  0.          1.          2.          3.        ]

# %% [markdown]
# # plot diagram

# %%
plt.plot(x,output,label='Elu',color='green')
plt.title('Elu Activation Function')
plt.xlabel('Input')
plt.ylabel('Elu Output')
plt.grid(True)
plt.legend()
plt.show()
# Expected output: A plot showing the ELU function, which is alpha * (exp(x) - 1) for negative inputs and linear for positive inputs.

# %% [markdown]
# # Sigmoid functin(Binary class problem)

# %%
# formula
#y=1/(1+exp(-x))
def sigmoid(x):
    return 1/(1+np.exp(-x))
# Expected output: 1/(1+exp(-x)) for all x

# %%
x= np.array([-1, 0, 1, 2, 3])
output=sigmoid(x)
print("Sigmoid Output:", output)
# Expected output: [0.26894142 0.5        0.73105858 0.88079708 0.95257413]

# %% [markdown]
# # Plotting diagram

# %%
plt.plot(x, output, label='ELU', color='blue')
plt.title('Sigmoid Activation Function')
plt.xlabel('Input')
plt.ylabel('Sigmoid Output')
plt.grid(True)
plt.show()
# Expected output: A plot showing the sigmoid function, which is S-shaped and asymptotes to 0 and 1.
